# %%
import numpy as np
import xarray as xr
import rioxarray
import matplotlib.pyplot as plt

# %%
srtm = rioxarray.open_rasterio(r"C:/Users/cclark/Documents/408/Class_Exercise_7/N34W087.SRTMGL1.hgt/N34W087.hgt")
srtm
pixel_area = srtm.rio.resolution()
srtm['x']
# Out:
# <xarray.DataArray 'x' (x: 3601)> Size: 29kB
# array([-87.      , -86.999722, -86.999444, ..., -86.000556, -86.000278,
#        -86.      ], shape=(3601,))
# Coordinates:
#   * x            (x) float64 29kB -87.0 -87.0 -87.0 -87.0 ... -86.0 -86.0 -86.0
#     spatial_ref  int64 8B 0

# %%
total_over500 = 0
x_coords = srtm['x']
y_coords = srtm['y']
for point in srtm:
    pixel_value = srtm.sel(band=1, x=x_coords(point), y=y_coords(point), method='nearest')
    pixel_value = pixel_value.values
    if pixel_value > 500:
        total_over500 += 1

total_over500
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 5
#       3 y_coords = srtm['y']
#       4 for point in srtm:
# ----> 5     pixel_value = srtm.sel(band=1, x=x_coords(point), y=y_coords(point), method='nearest')
#       6     pixel_value = pixel_value.values
#       7     if pixel_value > 500:
#
# TypeError: 'DataArray' object is not callable

# %%
pixel_value = srtm.sel(band=1, x=-86.0, y=35.0, method='nearest')
pixel_value.values
# Out:
# array(459, dtype=int16)
